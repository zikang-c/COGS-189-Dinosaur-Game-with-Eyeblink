# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('BrainFlow-RAW_2023-02-23_11-15-45_11.csv')

# %%
df = df.loc[6:,:]

data = df.iloc[:,1:9]
time = df.iloc[:, -2]

# %%
data
# Out:
#        19642.400103  17894.448983  0.000000  0.000000.1  0.000000.2  \
# 6      16726.279763  16715.215649       0.0         0.0         0.0
# 7      16722.815242  16715.238001       0.0         0.0         0.0
# 8      16720.267143  16709.806527       0.0         0.0         0.0
# 9      16725.452748  16707.660759       0.0         0.0         0.0
# 10     16727.173832  16705.582047       0.0         0.0         0.0
# ...             ...           ...       ...         ...         ...
# 10447  10255.494446  15197.442794       0.0         0.0         0.0
# 10448  10275.231037  15217.492308       0.0         0.0         0.0
# 10449  10260.925920  15239.106445       0.0         0.0         0.0
# 10450  10252.611071  15224.510756       0.0         0.0         0.0
# 10451  10268.905493  15218.341675       0.0         0.0         0.0
#
#        0.000000.3  0.000000.4  0.000000.5
# 6             0.0         0.0         0.0
# 7             0.0         0.0         0.0
# ...

# %%
plt.plot(time, data);
plt.xlabel('Time (s)');
plt.ylabel('uV');
